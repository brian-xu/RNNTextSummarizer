# %% [markdown]
# This file was used for preprocessing text.

# %%
## Lowercasing

# %%
final_text = "Ever noticed how plane seats appear to be getting smaller and smaller? With increasing numbers of people taking to the skies, some experts are questioning if having such packed out planes is putting passengers at risk. They say that the shrinking space on aeroplanes is not only uncomfortable - it's putting our health and safety in danger. More than squabbling over the arm rest, shrinking space on planes putting our health and safety in danger? This week, a U.S consumer advisory group set up by the Department of Transportation said at a public hearing that while the government is happy to set standards for animals flying on planes, it doesn't stipulate a minimum amount of space for humans. 'In a world where animals have more rights to space and food than humans,' said Charlie Leocha, consumer representative on the committee.Â 'It is time that the DOT and FAA take a stand for humane treatment of passengers.' But could crowding on planes lead to more serious issues than fighting for space in the overhead lockers, crashing elbows and seat back kicking? Tests conducted by the FAA use planes with a 31 inch pitch, a standard which on some airlines has decreased . Many economy seats on United Airlines have 30 inches of room, while some airlines offer as little as 28 inches . Cynthia Corbertt, a human factors researcher with the Federal Aviation Administration, that it conducts tests on how quickly passengers can leave a plane. But these tests are conducted using planes with 31 inches between each row of seats, a standard which on some airlines has decreased, reported the Detroit News. The distance between two seats from one point on a seat to the same point on the seat behind it is known as the pitch. While most airlines stick to a pitch of 31 inches or above, some fall below this. While United Airlines has 30 inches of space, Gulf Air economy seats have between 29 and 32 inches, Air Asia offers 29 inches and Spirit Airlines offers just 28 inches. British Airways has a seat pitch of 31 inches, while easyJet has 29 inches, Thomson's short haul seat pitch is 28 inches, and Virgin Atlantic's is 30-31."

# %%
texts = final_text.split()
lower_words=[word.lower() for word in texts]
lower_words
# Out:
# ['ever',
#  'noticed',
#  'how',
#  'plane',
#  'seats',
#  'appear',
#  'to',
#  'be',
#  'getting',
#  'smaller',
#  'and',
#  'smaller?',
#  'with',
#  'increasing',
#  'numbers',
#  'of',
#  'people',
#  'taking',
#  'to',
#  'the',
#  'skies,',
#  'some',
#  'experts',
#  'are',
#  'questioning',
#  'if',
#  'having',
#  'such',
#  'packed',
#  'out',
#  'planes',
#  'is',
#  'putting',
#  'passengers',
#  'at',
#  'risk.',
#  'they',
#  'say',
#  'that',
#  'the',
#  'shrinking',
#  'space',
#  'on',
#  'aeroplanes',
#  'is',
#  'not',
#  'only',
#  'uncomfortable',
#  '-',
#  "it's",
#  'putting',
#  'our',
#  'health',
#  'and',
#  'safety',
#  'in',
#  'danger.',
#  'more',
#  'than',
#  'squabbling',
#  'over',
#  'the',
#  'arm',
#  'rest,',
#  'shrinking',
#  'space',
#  'on',
#  'planes',
#  'putting',
#  'our',
#  'health',
#  'and',
#  'safety',
#  'in',
#  'danger?',
#  'this',
#  'week,',
#  'a',
#  'u.s',
#  'consumer',
#  'advisory',
#  'group',
#  'set',
#  'up',
#  'by',
#  'the',
#  'department',
#  'of',
#  'transportation',
#  'said',
#  'at',
#  'a',
#  'public',
#  'hearing',
#  'that',
#  'while',
#  'the',
#  'government',
#  'is',
#  'happy',
#  'to',
#  'set',
#  'standards',
#  'for',
#  'animals',
#  'flying',
#  'on',
#  'planes,',
#  'it',
#  "doesn't",
#  'stipulate',
#  'a',
#  'minimum',
#  'amount',
#  'of',
#  'space',
#  'for',
#  'humans.',
#  "'in",
#  'a',
#  'world',
#  'where',
#  'animals',
#  'have',
#  'more',
#  'rights',
#  'to',
#  'space',
#  'and',
#  'food',
#  'than',
#  "humans,'",
#  'said',
#  'charlie',
#  'leocha,',
#  'consumer',
#  'representative',
#  'on',
#  'the',
#  'committee.â',
#  "'it",
#  'is',
#  'time',
#  'that',
#  'the',
#  'dot',
#  'and',
#  'faa',
#  'take',
#  'a',
#  'stand',
#  'for',
#  'humane',
#  'treatment',
#  'of',
#  "passengers.'",
#  'but',
#  'could',
#  'crowding',
#  'on',
#  'planes',
#  'lead',
#  'to',
#  'more',
#  'serious',
#  'issues',
#  'than',
#  'fighting',
#  'for',
#  'space',
#  'in',
#  'the',
#  'overhead',
#  'lockers,',
#  'crashing',
#  'elbows',
#  'and',
#  'seat',
#  'back',
#  'kicking?',
#  'tests',
#  'conducted',
#  'by',
#  'the',
#  'faa',
#  'use',
#  'planes',
#  'with',
#  'a',
#  '31',
#  'inch',
#  'pitch,',
#  'a',
#  'standard',
#  'which',
#  'on',
#  'some',
#  'airlines',
#  'has',
#  'decreased',
#  '.',
#  'many',
#  'economy',
#  'seats',
#  'on',
#  'united',
#  'airlines',
#  'have',
#  '30',
#  'inches',
#  'of',
#  'room,',
#  'while',
#  'some',
#  'airlines',
#  'offer',
#  'as',
#  'little',
#  'as',
#  '28',
#  'inches',
#  '.',
#  'cynthia',
#  'corbertt,',
#  'a',
#  'human',
#  'factors',
#  'researcher',
#  'with',
#  'the',
#  'federal',
#  'aviation',
#  'administration,',
#  'that',
#  'it',
#  'conducts',
#  'tests',
#  'on',
#  'how',
#  'quickly',
#  'passengers',
#  'can',
#  'leave',
#  'a',
#  'plane.',
#  'but',
#  'these',
#  'tests',
#  'are',
#  'conducted',
#  'using',
#  'planes',
#  'with',
#  '31',
#  'inches',
#  'between',
#  'each',
#  'row',
#  'of',
#  'seats,',
#  'a',
#  'standard',
#  'which',
#  'on',
#  'some',
#  'airlines',
#  'has',
#  'decreased,',
#  'reported',
#  'the',
#  'detroit',
#  'news.',
#  'the',
#  'distance',
#  'between',
#  'two',
#  'seats',
#  'from',
#  'one',
#  'point',
#  'on',
#  'a',
#  'seat',
#  'to',
#  'the',
#  'same',
#  'point',
#  'on',
#  'the',
#  'seat',
#  'behind',
#  'it',
#  'is',
#  'known',
#  'as',
#  'the',
#  'pitch.',
#  'while',
#  'most',
#  'airlines',
#  'stick',
#  'to',
#  'a',
#  'pitch',
#  'of',
#  '31',
#  'inches',
#  'or',
#  'above,',
#  'some',
#  'fall',
#  'below',
#  'this.',
#  'while',
#  'united',
#  'airlines',
#  'has',
#  '30',
#  'inches',
#  'of',
#  'space,',
#  'gulf',
#  'air',
#  'economy',
#  'seats',
#  'have',
#  'between',
#  '29',
#  'and',
#  '32',
#  'inches,',
#  'air',
#  'asia',
#  'offers',
#  '29',
#  'inches',
#  'and',
#  'spirit',
#  'airlines',
#  'offers',
#  'just',
#  '28',
#  'inches.',
#  'british',
#  'airways',
#  'has',
#  'a',
#  'seat',
#  'pitch',
#  'of',
#  '31',
#  'inches,',
#  'while',
#  'easyjet',
#  'has',
#  '29',
#  'inches,',
#  "thomson's",
#  'short',
#  'haul',
#  'seat',
#  'pitch',
#  'is',
#  '28',
#  'inches,',
#  'and',
#  'virgin',
#  "atlantic's",
#  'is',
#  '30-31.']

# %%
## Stemming

# %%
import nltk
import pandas as pd
from nltk.stem import PorterStemmer

# init stemmer
porter_stemmer=PorterStemmer()

# %%
words = final_text.split()
stemmed_words=[porter_stemmer.stem(word=word) for word in words]

stemdf= pd.DataFrame({'original_word': words,'stemmed_word': stemmed_words})
stemdf
# Out:
#     original_word stemmed_word
# 0            Ever         ever
# 1         noticed        notic
# 2             how          how
# 3           plane        plane
# 4           seats         seat
# ..            ...          ...
# 365           and          and
# 366        Virgin       virgin
# 367    Atlantic's    atlantic'
# 368            is           is
# 369        30-31.       30-31.
#
# [370 rows x 2 columns]

# %%
## Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

# init lemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\19496\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.

# %%
#lemmatize trouble variations
words=final_text.split()
lemmatized_words=[lemmatizer.lemmatize(word=word,pos='v') for word in words]
lemmatizeddf= pd.DataFrame({'original_word': words,'lemmatized_word': lemmatized_words})
lemmatizeddf=lemmatizeddf[['original_word','lemmatized_word']]
lemmatizeddf
# Out:
#     original_word lemmatized_word
# 0            Ever            Ever
# 1         noticed          notice
# 2             how             how
# 3           plane           plane
# 4           seats            seat
# ..            ...             ...
# 365           and             and
# 366        Virgin          Virgin
# 367    Atlantic's      Atlantic's
# 368            is              be
# 369        30-31.          30-31.
#
# [370 rows x 2 columns]

# %%
## Stop Word Removal

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20572/3922961496.py in <module>
# ----> 1 import spacy
#       2 from spacy.lang.en.stop_words import STOP_WORDS
#
# ModuleNotFoundError: No module named 'spacy'

# %%
stopwords=list(STOP_WORDS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20572/3647108401.py in <module>
#       1 #stopwords=['this','that','and','a','we','it','to','is','of','up','need']
# ----> 2 stopwords=list(STOP_WORDS)
#       3 #text="this is a text full of content and we need to clean it up"
#
# NameError: name 'STOP_WORDS' is not defined

# %%
words = final_text.split()
shortlisted_words=[]

#remove stop words
for w in words:
    if w not in stopwords:
        shortlisted_words.append(w)
    else:
        shortlisted_words.append("W")

print("original sentence = ",final_text)    
print("sentence with stop words removed= ",' '.join(shortlisted_words))
# Out:
# original sentence =  Ever noticed how plane seats appear to be getting smaller and smaller? With increasing numbers of people taking to the skies, some experts are questioning if having such packed out planes is putting passengers at risk. They say that the shrinking space on aeroplanes is not only uncomfortable - it's putting our health and safety in danger. More than squabbling over the arm rest, shrinking space on planes putting our health and safety in danger? This week, a U.S consumer advisory group set up by the Department of Transportation said at a public hearing that while the government is happy to set standards for animals flying on planes, it doesn't stipulate a minimum amount of space for humans. 'In a world where animals have more rights to space and food than humans,' said Charlie Leocha, consumer representative on the committee.Â 'It is time that the DOT and FAA take a stand for humane treatment of passengers.' But could crowding on planes lead to more serious issues than fighting for space in the overhead lockers, crashing elbows and seat back kicking? Tests conducted by the FAA use planes with a 31 inch pitch, a standard which on some airlines has decreased . Many economy seats on United Airlines have 30 inches of room, while some airlines offer as little as 28 inches . Cynthia Corbertt, a human factors researcher with the Federal Aviation Administration, that it conducts tests on how quickly passengers can leave a plane. But these tests are conducted using planes with 31 inches between each row of seats, a standard which on some airlines has decreased, reported the Detroit News. The distance between two seats from one point on a seat to the same point on the seat behind it is known as the pitch. While most airlines stick to a pitch of 31 inches or above, some fall below this. While United Airlines has 30 inches of space, Gulf Air economy seats have between 29 and 32 inches, Air Asia offers 29 inches and Spirit Airlines offers just 28 inches. British Airways has a seat pitch of 31 inches, while easyJet has 29 inches, Thomson's short haul seat pitch is 28 inches, and Virgin Atlantic's is 30-31.
# sentence with stop words removed=  Ever noticed how plane seats appear W be getting smaller W smaller? With increasing numbers W people taking W the skies, some experts are questioning if having such packed out planes W putting passengers at risk. They say W the shrinking space on aeroplanes W not only uncomfortable - it's putting our health W safety in danger. More than squabbling over the arm rest, shrinking space on planes putting our health W safety in danger? This week, W U.S consumer advisory group set W by the Department W Transportation said at W public hearing W while the government W happy W set standards for animals flying on planes, W doesn't stipulate W minimum amount W space for humans. 'In W world where animals have more rights W space W food than humans,' said Charlie Leocha, consumer representative on the committee.Â 'It W time W the DOT W FAA take W stand for humane treatment W passengers.' But could crowding on planes lead W more serious issues than fighting for space in the overhead lockers, crashing elbows W seat back kicking? Tests conducted by the FAA use planes with W 31 inch pitch, W standard which on some airlines has decreased . Many economy seats on United Airlines have 30 inches W room, while some airlines offer as little as 28 inches . Cynthia Corbertt, W human factors researcher with the Federal Aviation Administration, W W conducts tests on how quickly passengers can leave W plane. But these tests are conducted using planes with 31 inches between each row W seats, W standard which on some airlines has decreased, reported the Detroit News. The distance between two seats from one point on W seat W the same point on the seat behind W W known as the pitch. While most airlines stick W W pitch W 31 inches or above, some fall below this. While United Airlines has 30 inches W space, Gulf Air economy seats have between 29 W 32 inches, Air Asia offers 29 inches W Spirit Airlines offers just 28 inches. British Airways has W seat pitch W 31 inches, while easyJet has 29 inches, Thomson's short haul seat pitch W 28 inches, W Virgin Atlantic's W 30-31.

# %%
## Noise Removal

# %%
import nltk
import pandas as pd
import re
from nltk.stem import PorterStemmer

porter_stemmer=PorterStemmer()

# %%
# stem raw words with noise
raw_words = final_text.split()
stemmed_words=[porter_stemmer.stem(word=word) for word in raw_words]
stemdf= pd.DataFrame({'raw_word': raw_words,'stemmed_word': stemmed_words})
stemdf
# Out:
#        raw_word stemmed_word
# 0          Ever         ever
# 1       noticed        notic
# 2           how          how
# 3         plane        plane
# 4         seats         seat
# ..          ...          ...
# 365         and          and
# 366      Virgin       virgin
# 367  Atlantic's    atlantic'
# 368          is           is
# 369      30-31.       30-31.
#
# [370 rows x 2 columns]

# %%
def scrub_words(text):
    # remove html markup
    text=re.sub("(<.*?>)","",text)
    
    #remove non-ascii and digits
    text=re.sub("(\\W|\\d)"," ",text)
    
    #remove whitespace
    text=text.strip()
    return text

# %%
# stem words already cleaned
cleaned_words=[scrub_words(w) for w in raw_words]
cleaned_stemmed_words=[porter_stemmer.stem(word=word) for word in cleaned_words]
stemdf= pd.DataFrame({'raw_word': raw_words,'cleaned_word':cleaned_words,'stemmed_word': cleaned_stemmed_words})
stemdf=stemdf[['raw_word','cleaned_word','stemmed_word']]
stemdf
# Out:
#        raw_word cleaned_word stemmed_word
# 0          Ever         Ever         ever
# 1       noticed      noticed        notic
# 2           how          how          how
# 3         plane        plane        plane
# 4         seats        seats         seat
# ..          ...          ...          ...
# 365         and          and          and
# 366      Virgin       Virgin       virgin
# 367  Atlantic's   Atlantic s    atlantic
# 368          is           is           is
# 369      30-31.
#
# [370 rows x 3 columns]
